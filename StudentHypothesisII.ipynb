# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Student-Info" data-toc-modified-id="Student-Info-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Student Info</a></span></li><li><span><a href="#Introduction" data-toc-modified-id="Introduction-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Introduction</a></span></li><li><span><a href="#Hypothesis-II" data-toc-modified-id="Hypothesis-II-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Hypothesis II</a></span></li><li><span><a href="#STEP-1:-Load-the-Data-and-determine-Test-Type" data-toc-modified-id="STEP-1:-Load-the-Data-and-determine-Test-Type-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>STEP 1: Load the Data and determine Test Type</a></span><ul class="toc-item"><li><span><a href="#Initialise-Libraries" data-toc-modified-id="Initialise-Libraries-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Initialise Libraries</a></span></li><li><span><a href="#Retrieve-data-from-database" data-toc-modified-id="Retrieve-data-from-database-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Retrieve data from database</a></span><ul class="toc-item"><li><span><a href="#Sample-Group-Design" data-toc-modified-id="Sample-Group-Design-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Sample Group Design</a></span></li></ul></li></ul></li><li><span><a href="#STEP-2:-Validate-Assumptions-chosen-test" data-toc-modified-id="STEP-2:-Validate-Assumptions-chosen-test-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>STEP 2: Validate Assumptions chosen test</a></span><ul class="toc-item"><li><span><a href="#Check-and-Remove-Outliers" data-toc-modified-id="Check-and-Remove-Outliers-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Check and Remove Outliers</a></span></li><li><span><a href="#Test-for-Normality" data-toc-modified-id="Test-for-Normality-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Test for Normality</a></span><ul class="toc-item"><li><span><a href="#Check-group-size" data-toc-modified-id="Check-group-size-5.2.1"><span class="toc-item-num">5.2.1&nbsp;&nbsp;</span>Check group size</a></span></li></ul></li><li><span><a href="#Test-for-Equal-Variance" data-toc-modified-id="Test-for-Equal-Variance-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Test for Equal Variance</a></span></li></ul></li><li><span><a href="#Step-3:-Run-Welch's-T-Test" data-toc-modified-id="Step-3:-Run-Welch's-T-Test-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Step 3: Run Welch's T-Test</a></span></li><li><span><a href="#STEP-4:-Interpret-Result-&amp;-Post-Hoc-Tests" data-toc-modified-id="STEP-4:-Interpret-Result-&amp;-Post-Hoc-Tests-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>STEP 4: Interpret Result &amp; Post-Hoc Tests</a></span><ul class="toc-item"><li><span><a href="#2-Sample-T-Test" data-toc-modified-id="2-Sample-T-Test-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>2 Sample T-Test</a></span></li><li><span><a href="#Effect-Size" data-toc-modified-id="Effect-Size-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Effect Size</a></span><ul class="toc-item"><li><span><a href="#Cohen's-d" data-toc-modified-id="Cohen's-d-7.2.1"><span class="toc-item-num">7.2.1&nbsp;&nbsp;</span>Cohen's d</a></span></li></ul></li><li><span><a href="#Multi-Sample-Data-Setup" data-toc-modified-id="Multi-Sample-Data-Setup-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>Multi Sample Data Setup</a></span><ul class="toc-item"><li><span><a href="#Check-and-Remove-Outliers" data-toc-modified-id="Check-and-Remove-Outliers-7.3.1"><span class="toc-item-num">7.3.1&nbsp;&nbsp;</span>Check and Remove Outliers</a></span></li><li><span><a href="#Test-for-Normality" data-toc-modified-id="Test-for-Normality-7.3.2"><span class="toc-item-num">7.3.2&nbsp;&nbsp;</span>Test for Normality</a></span></li><li><span><a href="#Check-group-sizes" data-toc-modified-id="Check-group-sizes-7.3.3"><span class="toc-item-num">7.3.3&nbsp;&nbsp;</span>Check group sizes</a></span></li><li><span><a href="#Test-for-Equal-Variance" data-toc-modified-id="Test-for-Equal-Variance-7.3.4"><span class="toc-item-num">7.3.4&nbsp;&nbsp;</span>Test for Equal Variance</a></span></li></ul></li><li><span><a href="#ANOVA-Test" data-toc-modified-id="ANOVA-Test-7.4"><span class="toc-item-num">7.4&nbsp;&nbsp;</span>ANOVA Test</a></span></li><li><span><a href="#Tukey's-Pairwise-Comparison" data-toc-modified-id="Tukey's-Pairwise-Comparison-7.5"><span class="toc-item-num">7.5&nbsp;&nbsp;</span>Tukey's Pairwise Comparison</a></span></li></ul></li><li><span><a href="#Final-Analysis-and-Recommendations" data-toc-modified-id="Final-Analysis-and-Recommendations-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Final Analysis and Recommendations</a></span><ul class="toc-item"><li><span><a href="#Recommendation-1:" data-toc-modified-id="Recommendation-1:-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Recommendation 1:</a></span></li><li><span><a href="#Recommendation-2:" data-toc-modified-id="Recommendation-2:-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>Recommendation 2:</a></span></li><li><span><a href="#Recommendation-3:" data-toc-modified-id="Recommendation-3:-8.3"><span class="toc-item-num">8.3&nbsp;&nbsp;</span>Recommendation 3:</a></span></li></ul></li><li><span><a href="#Additional-Hypothesis" data-toc-modified-id="Additional-Hypothesis-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Additional Hypothesis</a></span><ul class="toc-item"><li><span><a href="#Hypothesis-I" data-toc-modified-id="Hypothesis-I-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span><a href="hypothesis_i.ipynb" target="_blank">Hypothesis I</a></a></span></li><li><span><a href="#Hypothesis-III" data-toc-modified-id="Hypothesis-III-9.2"><span class="toc-item-num">9.2&nbsp;&nbsp;</span><a href="hypothesis_iii.ipynb" target="_blank">Hypothesis III</a></a></span></li><li><span><a href="#Hypothesis-IV" data-toc-modified-id="Hypothesis-IV-9.3"><span class="toc-item-num">9.3&nbsp;&nbsp;</span><a href="hypothesis_iv.ipynb" target="_blank">Hypothesis IV</a></a></span></li></ul></li></ul></div>

# %% [markdown]
# ## Student Info
# Name: Susanna Mir
# Cohort: DS-PT
# Instructor: James Irving

# %% [markdown]
# ********************************

# %% [markdown]
# ## Introduction
#
# The goal of the project is to query the Northwind database to get the data needed to perform a statistical analysis. In this statistical analysis, a hypothesis test will be perfomed to answer the following question:
#
# Does discount amount have a statistically significant effect on the quantity of a product in an order? If so, at what level(s) of discount?
#
#
# In addition to answering this question with a hypothesis test I, I have added 3 other hypotheses to test:
# >Hypothesis I  :  Does discount have a significant effect on the quantity of products in an order?
#
# >Hypothesis III :  Does the order month have a significant effect on the total spent on orders for that  >month?
#
# >Hypothesis IV :  Does the order month have a significant effect on the quantity orders for that month?

# %% [markdown]
# ********************************

# %% [markdown]
# ## Hypothesis II

# %% [markdown]
# >Does discount amount have a statistically significant effect on the total spent ($) on a product in an >order? If so, at what level(s) of discount?
#
# - $H_1$: Discount amount DOES have a statistically significant effect on the total spent on a product in an order.
# - $H_0$: Discount amount DOES NOT have a statistically significant effect on the total spent on a product in an order.
#
#
# Set the P-Value
# $\alpha$=0.05
# If the P-Value is < 0.5 we can be confident that we can reject the null hypothesis
#
# - $H_1$: What does it mean to be significant?  (P-Value< 0.5)
# An observed difference between the two groups is probably not due to chance
#
# - $H_0$: What does it mean to NOT be significant?  (P-Value> 0.5)
# There is not enough evidence to say that an observed difference between the two groups is not random.  (If there is a difference, it is smaller than we care about)

# %% [markdown]
# ********************************

# %% [markdown]
# ## STEP 1: Load the Data and determine Test Type

# %% [markdown]
# ### Initialise Libraries

# %%
import pandas as pd
import numpy as np
import sqlite3
import scipy.stats as stat
from scipy import stats

#data visualization imports
import matplotlib.pyplot as plt
import seaborn as sns

#for t-tests
from scipy.stats import ttest_ind

#for ANOVA
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.multicomp import pairwise_tukeyhsd
from statsmodels.stats.multicomp import MultiComparison

from scipy.stats import f_oneway

#for Project Library Functions
from functions import Cohen_d, find_outliers_IQR,find_outliers_Z
## Uncomment the line below to see the source code for the imported functions
# fs.ihelp(Cohen_d,False),fs.ihelp(find_outliers_IQR,False), fs.ihelp(find_outliers_Z,False)

# %% [markdown]
# ### Retrieve data from database

# %% [markdown]
# The schema below defines the tables and relationships for the database. The Order_Details table contains information with the columns of interest: [Quantity] [UnitPrice] and [Discount] by [Product_ID].

# %%
from IPython.display import Image
Image("Northwind_ERD.png")

# %%
# create a connection to the database
connect = sqlite3.connect('Northwind_small.sqlite')
cur = connect.cursor()

# %%
# view table definition
cur.execute("""SELECT name FROM sqlite_master WHERE type='table';""")
df_tables = pd.DataFrame(cur.fetchall(), columns=['Table'])
df_tables
# Out:
#                    Table
# 0               Employee
# 1               Category
# 2               Customer
# 3                Shipper
# 4               Supplier
# 5                  Order
# 6                Product
# 7            OrderDetail
# 8   CustomerCustomerDemo
# 9    CustomerDemographic
# 10                Region
# 11             Territory
# 12     EmployeeTerritory

# %%
# query the database
cur.execute("SELECT * FROM OrderDetail;")

# store results in a dataframe
df_order_details = pd.DataFrame(cur.fetchall())
df_order_details.columns = [i[0] for i in cur.description]

# check the import
df_order_details.head()
# Out:
#          Id  OrderId  ProductId  UnitPrice  Quantity  Discount
# 0  10248/11    10248         11       14.0        12       0.0
# 1  10248/42    10248         42        9.8        10       0.0
# 2  10248/72    10248         72       34.8         5       0.0
# 3  10249/14    10249         14       18.6         9       0.0
# 4  10249/51    10249         51       42.4        40       0.0

# %%
## Data Clean check - are there any null values?

# %%
# # query the database
# cur.execute("SELECT * FROM OrderDetail;")

# # store results in a dataframe
# df_order_details_total_spent = pd.DataFrame(cur.fetchall())

# %%
df_order_details.isna().sum()
# Out:
# Id           0
# OrderId      0
# ProductId    0
# UnitPrice    0
# Quantity     0
# Discount     0
# dtype: int64

# %%
# no null values found

# %% [markdown]
# #### Sample Group Design

# %% [markdown]
# >What type of data do I have (Numeric or categorical?)
# >- Numerical - 2 Sample T-Test
#
# >How many samples/groups am I comparing? =
# >- 2 therefore focus on using a 2 Sample T-Test

# %%
## Create 'discounted' column for groupby 
df_order_details['discounted'] = df_order_details['Discount']>0
df_order_details['discounted'] = df_order_details['discounted'].map({True:'Discounted',False:'Full Price'})
df_order_details
# Out:
#             Id  OrderId  ProductId  UnitPrice  Quantity  Discount  discounted
# 0     10248/11    10248         11      14.00        12      0.00  Full Price
# 1     10248/42    10248         42       9.80        10      0.00  Full Price
# 2     10248/72    10248         72      34.80         5      0.00  Full Price
# 3     10249/14    10249         14      18.60         9      0.00  Full Price
# 4     10249/51    10249         51      42.40        40      0.00  Full Price
# 5     10250/41    10250         41       7.70        10      0.00  Full Price
# 6     10250/51    10250         51      42.40        35      0.15  Discounted
# 7     10250/65    10250         65      16.80        15      0.15  Discounted
# 8     10251/22    10251         22      16.80         6      0.05  Discounted
# 9     10251/57    10251         57      15.60        15      0.05  Discounted
# 10    10251/65    10251         65      16.80        20      0.00  Full Price
# 11    10252/20    10252         20      64.80        40      0.05  Discounted
# 12    10252/33    10252         33       2.00        25      0.05  Discounted
# 13    10252/60    10252         60      27.20        40      0.00  Full Price
# 14    10253/31    10253         31      10.00        20      0.00  Full Price
# 15    10253/39    10253         39      14.40        42      0.00  Full Price
# 16    10253/49    10253         49      16.00        40      0.00  Full Price
# 17    10254/24    10254         24       3.60        15      0.15  Discounted
# 18    10254/55    10254         55      19.20        21      0.15  Discounted
# 19    10254/74    10254         74       8.00        21      0.00  Full Price
#  2107     364.80
#  2108    1656.00
#  2109     364.00
#  2111     720.00
#  2112     380.00
#  2113     523.50
#  2115     450.00
#  2116      60.00
#  2123     244.30
#  2124     190.00
#  2125     360.00
#  2126      36.00
#  2127     500.00
#  2128     465.00
#  2129      92.00
#  2130     456.00
#  2133      25.00
#  2134      30.00
#  2135      80.00
#  2137      76.00
#  2139      23.25
#  2140      34.90
#  2141      81.00
#  2144      36.00
#  2146      36.00
#  2149      68.00
#  2150      66.50
#  2152      30.00
#  Name: Total Spent, Length: 838, dtype: float64}

# %%
plt.figure(figsize=(20, 10))
[sns.distplot(v,label=k) for k,v in grps.items()]
plt.legend()
plt.legend(fontsize=20);
# Out:
# /Users/SusannaVSyassen/anaconda3/envs/learn-env/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ********************************

# %% [markdown]
# ## STEP 2: Validate Assumptions chosen test

# %% [markdown]
# For the Independent 2 Sample T-Test the assumptions are:
#
# - There exists NO significant outliers
# - Normality is true
# - Equal Variance is true

# %% [markdown]
# ### Check and Remove Outliers

# %% [markdown]
# Use absolutely value of Z-scores >3 as rule to find and remove outliers

# %%
from functions import find_outliers_Z

# %%
for grp_name,grp_data in grps.items():
    idx_outs = find_outliers_Z(grp_data)
    print(f"[i] Found {idx_outs.sum()} outliers using Z-score method for {grp_name}.")
    grps[grp_name] = grp_data[~idx_outs]
# Out:
# [i] Found 19 outliers using Z-score method for Full Price.
# [i] Found 13 outliers using Z-score method for Discounted.

# %%
plt.figure(figsize=(20, 10))
[sns.distplot(v,label=k) for k,v in grps.items()]
ax = plt.gca()
ax.legend()
ax.set(title='Quantity on Full Price vs Discounted Products',
ylabel='Density')
plt.legend(fontsize=20);
# Out:
# /Users/SusannaVSyassen/anaconda3/envs/learn-env/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ### Test for Normality

# %% [markdown]
# Test Assumption of Normality using D'Agostino-Pearson's normality test scipy.stats.normaltest

# %%
for k,v in grps.items():
    stat,p = stats.normaltest(v)
    print(f"Group {k} Normaltest p-value={round(p,4)}")
    sig = 'is NOT' if p<.05 else 'IS'

    print(f"\t-The data {sig} normal.")
# Out:
# Group Full Price Normaltest p-value=0.0
# 	-The data is NOT normal.
# Group Discounted Normaltest p-value=0.0
# 	-The data is NOT normal.

# %% [markdown]
# If there is normal data move onto assumption testing assumption of equal variance.
# The data is NOT normal, Check if your group sizes (n) are big enough to safely ignore normality assumption? (see size definitions below)
#
# Parametric Test	Sample size guidelines for nonnormal data
# - 1-sample t test	Greater than 20
# - 2-sample t test	Each group should be greater than 15
# - One-Way ANOVA	If have 2-9 groups, each group n >= 15
#   If have 10-12 groups, each group n>20.
#
# If the group N's are NOT large enough:
# Move onto selecting the non-parametric version of the t-test
#
# >As we are doing a 2-Sample T Test, test to see if the group n>= 15.

# %% [markdown]
# #### Check group size

# %%
for grp_name,grp_data in grps.items():
    print(f"Total size n for {grp_name} is {len(grps[grp_name])}")
# Out:
# Total size n for Full Price is 1298
# Total size n for Discounted is 825

# %% [markdown]
# >Group size is large enough (>15) to safely ignore normality assumption to continue 2 Sample T-Test

# %% [markdown]
# ### Test for Equal Variance

# %% [markdown]
# Data is large enough, move onto testing for equal variance.
#
# - If it fails the assumption of equal variance: Use a Welch's T-Test.
#     (For scipy, add equal_var=False to ttest_ind)
# - If it passes the assumption of equal variance: Use a regular 2-sample t-test.

# %%
data=[]
for k,v in grps.items():

    data.append(v.values)

# %%
stat,p = stats.levene(*data)
print(f"Levene' Test for Equal Variance p-value={round(p,4)}")
sig = 'do NOT' if p<.05 else 'DO'

print(f"\t-The groups {sig} have equal variance.")
# Out:
# Levene' Test for Equal Variance p-value=0.0
# 	-The groups do NOT have equal variance.

# %% [markdown]
# If the resulting p-value of Levene's test is less than the p-value 0.05, the obtained differences in sample variances are unlikely to have occurred based on random sampling from a population with equal variances.
#
# >Equal Variance test failed, run Welch's T-Test.
#
# Traditional t-tests assume that sample sizes and sample variances between the two groups are equal.
# When these assumptions are not met, Welch's t-test is generally a more reliable test.

# %% [markdown]
# ********************************

# %% [markdown]
# ## Step 3: Run Welch's T-Test

# %% [markdown]
# Use Mann Whitney test if the group size is not big enough otherwise continue with Welch's T-Test
# ##stat,p = stats.mannwhitneyu(data[0],data[1])
# ##print(f"Mann Whitney U p-value={round(p,4)}")

# %%
# create control and experimental groups
# put items without the variable we are curious about into control group
control = df_order_details[df_order_details['Discount'] == 0]
ctrl = control['Total Spent']

# put items with the variable we are curious about into experimental group
experimental = df_order_details[df_order_details['Discount'] != 0]
exp = experimental["Total Spent"]

# %%
def welch_ttest(x, y): 
    ## Welch-Satterthwaite Degrees of Freedom ##
    dof = (x.var()/x.size + y.var()/y.size)**2 / ((x.var()/x.size)**2 / (x.size-1) + (y.var()/y.size)**2 / (y.size-1))
   
    t, p = stats.ttest_ind(x, y, equal_var = False)
    
    print("\n",
          f"Welch's t-test= {t:.4f}", "\n",
          f"p-value = {p:.4f}", "\n",
          f"Welch-Satterthwaite Degrees of Freedom= {dof:.4f}")

welch_ttest(ctrl, exp)
# Out:
#  Welch's t-test= -3.1721
#  p-value = 0.0015
#  Welch-Satterthwaite Degrees of Freedom= 1563.3782

# %% [markdown]
# ********************************

# %% [markdown]
# ## STEP 4: Interpret Result & Post-Hoc Tests

# %% [markdown]
# If the P-Value is < $\alpha$:
# - Reject the null hypothesis
# - Calculate the effect size (e.g. Cohen's $d$)
#
# If the P-Value <$\alpha$ AND you have multiple groups:
# - Run ANOVA Test
# - Run a pairwise Tukey's test to know which groups were significantly different
# - Report statistical power (optional)

# %% [markdown]
# ### 2 Sample T-Test

# %% [markdown]
# >As the results showed NO equal variance or normality add parameter equal_var=false to the 2 Sample T-Test, >this should match Welch's T-Test results.
#
# The two-sample t-test is used to determine if two population means are equal.
#
# ($\alpha$) is set to 0.05 or 5%: This the $\alpha$ value we are comfortable with for making a Type I error.
#
# In order to reduce the probability of type errors, it is best to have a large sample.
#
# - Type I error: reject alternative hypothesis  but the discount has no effect on quantity purchased.
#
# - Type II error: accept null hypothesis but the discount has effect on quantity purchased.

# %%
# #ttest_ind(exp_mean_quantity.values, ctrl_mean_quantity.values ) --- catch output and round down
# stat,p = ttest_ind(grps['Full Price'],grps['Discounted'], equal_var=False)
# ttest_ind(grps['Full Price'],grps['Discounted'], equal_var=False)
# #catch output and round down
# print(f"2 Sample T-Test U p-value={round(p,5)}")

# %% [markdown]
# P-Value is < 0.5, Reject the null hypothesis
#
# - $H_1$: Discount amount DOES have a statistically significant effect on the total spent on a product in an order.
# - $H_0$: Discount amount DOES NOT have a statistically significant effect on the total spent on a product in an order.

# %% [markdown]
# >We now need to continue to discover why the results show that discount DOES have a significant on total >spent (h1)

# %% [markdown]
# ### Effect Size

# %% [markdown]
# How big is the difference between the two groups where discount amount DOES have a statistically significant effect on the total spent on a product in an order?
#
# Calculate the effect size using Cohen's $d$

# %% [markdown]
# #### Cohen's d

# %%
d=Cohen_d(grps['Discounted'],grps['Full Price'])
#catch output and round down
print(f"Cohens D result = {round(d,5)}")
# Out:
# Cohens D result = 0.22821

# %% [markdown]
# The details below define how to read the results for Cohen's D:
# - Small effect = 0.2 (cannot be seen by naked eye)
# - Medium effect = 0.5
# - Large Effect = 0.8 (can be seen by naked eye)
#
# This Cohen's d value = 0.28811, therefore discount has a Slightly Higher SMALL EFFECT on the total spent on product sold.

# %% [markdown]
# ********************************

# %% [markdown]
# ### Multi Sample Data Setup

# %% [markdown]
# As the P-Value < .05 AND we have multiple groups run ANOVA to see further the difference between the groups.
# ANOVA (Analysis of Variance) is a method for generalizing statistical tests to multiple groups.

# %% [markdown]
# >Setup and Analyze multi sample data for ANOVA and Tukeys

# %%
plt.figure(figsize=(20, 10))
[sns.distplot(v,label=k) for k,v in grps.items()]
plt.legend()
plt.legend(fontsize=20);
# Out:
# /Users/SusannaVSyassen/anaconda3/envs/learn-env/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.barplot(data = df_order_details, x="Discount", y="Total Spent", ci=68)
# Out:
# /Users/SusannaVSyassen/anaconda3/envs/learn-env/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# #### Check and Remove Outliers

# %%
from functions import find_outliers_Z

# %%
for grp_name,grp_data in grps.items():
    idx_outs = find_outliers_Z(grp_data)
    print(f"[i] Found {idx_outs.sum()} outliers using Z-score method for {grp_name}.")
    grps[grp_name] = grp_data[~idx_outs]
# Out:
# [i] Found 32 outliers using Z-score method for Full Price.
# [i] Found 15 outliers using Z-score method for Discounted.

# %% [markdown]
# #### Test for Normality

# %%
for k,v in grps.items():
    if len(v) > 8:
        stat,p = stats.normaltest(v)
        print(f"Group {k} Normaltest p-value={round(p,4)}")
        sig = 'is NOT' if p<.05 else 'IS'
        print(f"\t-The data {sig} normal.")
    else:
        print(f"\t-The group {k} has too few samples.")
# Out:
# Group Full Price Normaltest p-value=0.0
# 	-The data is NOT normal.
# Group Discounted Normaltest p-value=0.0
# 	-The data is NOT normal.

# %%
# list_pop = [0.01]
# for group in list_pop:
#     grps.pop(group)

# %%
df_order_details = df_order_details[~all_outliers_combined]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-cee6386bfacd> in <module>()
# ----> 1 df_order_details = df_order_details[~all_outliers_combined]
#
# NameError: name 'all_outliers_combined' is not defined

# %%
from functions import prep_data_for_tukeys
df_data = prep_data_for_tukeys(grps)
df_data.head()
ax = sns.barplot(data = df_data, x="group", y="data", ci=68)
ax.set(xlabel = "Discount", ylabel = "Total Spent")

# %% [markdown]
# #### Check group sizes

# %% [markdown]
# - One-Way ANOVA	If have 2-9 groups, each group n >= 15
#   If have 10-12 groups, each group n>20.

# %%
for grp_name,grp_data in grps.items():
    print(f"Total size n for {grp_name} is {len(grps[grp_name])}")

# %% [markdown]
# >Group size is large enough (>15) to safely ignore normality assumption to continue ANOVA.

# %% [markdown]
# #### Test for Equal Variance

# %%
data=[]
for k,v in grps.items():

    data.append(v.values)

# %%
stat,p = stats.levene(*data)
print(f"Levene' Test for Equal Variance p-value={round(p,4)}")
sig = 'do NOT' if p<.05 else 'DO'

print(f"\t-The groups {sig} have equal variance.")

# %% [markdown]
# ### ANOVA Test

# %%
#f_oneway(ctrl_mean_quantity, exp_mean_quantity)
stat,p = f_oneway(*data)
print(f"Anova Results stat = {stat} p = {round(p,5)}")

# %% [markdown]
# If the P-Value is < $\alpha$:
# - Reject the null hypothesis
# - Calculate the effect size (e.g. Cohen's $d$)
#
# If the P-Value <$\alpha$ AND you have multiple groups:
# - Run a pairwise Tukey's test to know which groups were significantly different
# - Report statistical power (optional)

# %% [markdown]
# >We now need to continue to discover why the results show that discount DOES have a significant effect on >price (h1)

# %% [markdown]
# ### Tukey's Pairwise Comparison

# %% [markdown]
# There is a significant difference between the groups of discounts, but
# Anova does not specify which ones.  Run Tukey's comparison to further discover the difference
# between each discount value.

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
tukeys = pairwise_tukeyhsd(df_data["Total Spent"], df_data["Discount"])
tukeys.summary()

# %% [markdown]
# ********************************

# %% [markdown]
# ## Final Analysis and Recommendations

# %% [markdown]
# The Null Hypothesis is rejected as the P-Value was < 0.5
#
# ### Recommendation 1:
#
# As seen from the Tukey's T-Test the discounts 0.5, 0.25 had a statistically significant
# effect on the Total Spent of products ordered therefore H1 (Alternative Hypothesis) is True.
#
# group1 group2  meandiff   lower      upper   reject
# -  0.0    0.05   269.9216   8.4896    531.3536  True
# -  0.0    0.25   286.6044   3.0375    570.1714  True
#
# The discounts 0.5 and 0.25 had similar results from the Tukey's T-Test with the following results:
# group1 group2  meandiff   lower      upper   reject
# -  0.0    0.05   269.9216   8.4896    531.3536  True
# -  0.0    0.25   286.6044   3.0375    570.1714  True
#
#  with an average meandiff of 269.9216 for 0.5 discount and 286.6044 for 0.25 discount.
#
# therefore it is recommended from a business profitability perspective, that as there is very little
# difference between the total spent on products sold at 5% as compared to 20%, it may be of further
# interest to research if the company would profit from just offering 5% discounts.
#
# ### Recommendation 2:
# According to the Cohen's D effect size results, discount does have a Slightly Higher LOW significant effect on quantity sold.
#
# ### Recommendation 3:
# There was a large difference (36%) in  groups sample sizes for testing between Full Price and Discounted orders, it would be recommended to test on a sample size where Full Price products and Discounted product sample sizes were more equal.
# Total size n for Full Price is 1298
# Total size n for Discounted is 825

# %% [markdown]
# ## Additional Hypothesis

# %% [markdown]
# ### [Hypothesis I](hypothesis_i.ipynb)
# Does discount have a significant effect on the quantity of products in an order?

# %% [markdown]
# ### [Hypothesis III](hypothesis_iii.ipynb)
# Does the order month have a significant effect on the total spent on orders for that month?

# %% [markdown]
# ### [Hypothesis IV](hypothesis_iv.ipynb)
# Does the order month have a significant effect on the quantity on orders for that month?
